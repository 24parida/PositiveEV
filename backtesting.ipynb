# %%
import requests
import urllib
from datetime import datetime

BASE_URL = 'https://api.prop-odds.com'
API_KEY = 'qL5VXnhAyK6cLbKzpD45yfLKdMzoCcepZXQJWs2o'


def get_request(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()

    print('Request failed with status:', response.status_code)
    return {}


def get_nba_games():
    now = datetime.now()
    query_params = {
        # 'date': now.strftime('%Y-%m-%d'),
        'date': "2024-01-01",
        'tz': 'America/New_York',
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/games/nba?' + params
    return get_request(url)


def get_game_info(game_id):
    query_params = {
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/game/' + game_id + '?' + params
    return get_request(url)


def get_markets(game_id):
    query_params = {
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/markets/' + game_id + '?' + params
    return get_request(url)


def get_most_recent_odds(game_id, market):
    query_params = {
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/odds/' + game_id + '/' + market + '?' + params
    return get_request(url)


def get_fantasy_lines(game_id, market):
    query_params = {
        'api_key': API_KEY,
    }

    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/fantasy_lines/' + game_id + '/' + market + '?' + params
    return get_request(url)

# %%
games = get_nba_games()
game_ids = [i['game_id'] for i in games['games']]
markets = ['player_rebounds_over_under', 'player_points_rebounds_over_under', \
           'player_points_over_under', 'player_blocks_steals_over_under', \
            'player_blocks_over_under', 'player_assists_rebounds_over_under', \
            'player_assists_rebounds_over_under', 'player_assists_points_rebounds_over_under', \
            'player_assists_points_over_under', 'player_assists_over_under', 'player_steals_over_under', 'player_threes_over_under']

dates = []
for date in dates:
    games = get_nba_games()
    game_ids = [i['game_id'] for i in games['games']]
    
    for game in games:
        for market in markets:
            underdog = get_fantasy_lines(game, market)
            books = get_most_recent_odds(game, market)
# Out:
# {'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#  'fantasy_books': [{'bookie_key': 'draftkings',
#    'market': {'market_key': 'player_assists_over_under',
#     'lines': [{'timestamp': '2024-01-26T16:55:03.067797',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 1.5,
#       'participant': 379,
#       'participant_name': 'Deandre Ayton'},
#      {'timestamp': '2024-01-26T14:05:02.870543',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 5.5,
#       'participant': 769,
#       'participant_name': 'Malcolm Brogdon'},
#      {'timestamp': '2024-01-26T16:55:03.067923',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 5.5,
#       'participant': 16162,
#       'participant_name': 'Anfernee Simons'},
#      {'timestamp': '2024-01-26T14:05:02.870922',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 3.5,
#       'participant': 16257,
#       'participant_name': 'Victor Wembanyama'},
#      {'timestamp': '2024-01-26T16:55:03.068037',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 5.5,
#       'participant': 16258,
#       'participant_name': 'Devin Vassell'},
#      {'timestamp': '2024-01-26T20:10:02.883730',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 3.5,
#       'participant': 16259,
#       'participant_name': 'Jeremy Sochan'},
#      {'timestamp': '2024-01-26T14:05:02.870656',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 7.5,
#       'participant': 16260,
#       'participant_name': 'Tre Jones'}]}},
#   {'bookie_key': 'prizepicks',
#    'market': {'market_key': 'player_assists_over_under',
#     'lines': [{'timestamp': '2024-01-27T01:50:16.517620',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 6.0,
#       'participant': 769,
#       'participant_name': 'Malcolm Brogdon'},
#      {'timestamp': '2024-01-27T02:10:11.828870',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 5.0,
#       'participant': 16160,
#       'participant_name': 'Scoot Henderson'},
#      {'timestamp': '2024-01-27T01:55:11.990335',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 6.5,
#       'participant': 16162,
#       'participant_name': 'Anfernee Simons'},
#      {'timestamp': '2024-01-27T01:10:11.625250',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 3.5,
#       'participant': 16257,
#       'participant_name': 'Victor Wembanyama'},
#      {'timestamp': '2024-01-27T00:45:14.782767',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 4.0,
#       'participant': 16258,
#       'participant_name': 'Devin Vassell'},
#      {'timestamp': '2024-01-27T01:10:11.625285',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 7.0,
#       'participant': 16260,
#       'participant_name': 'Tre Jones'},
#      {'timestamp': '2024-01-27T01:15:11.342836',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 1.5,
#       'participant': 17203,
#       'participant_name': 'Cedi Osman'}]}},
#   {'bookie_key': 'underdog',
#    'market': {'market_key': 'player_assists_over_under',
#     'lines': [{'timestamp': '2024-01-27T02:05:24.991636',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 0.5,
#       'participant': 55,
#       'participant_name': 'Mikko Rantanen'},
#      {'timestamp': '2024-01-27T02:40:23.489219',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 2.0,
#       'participant': 369,
#       'participant_name': 'Kevon Looney'},
#      {'timestamp': '2024-01-27T01:45:26.481362',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 1.5,
#       'participant': 379,
#       'participant_name': 'Deandre Ayton'},
#      {'timestamp': '2024-01-27T02:40:23.489046',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 2.5,
#       'participant': 397,
#       'participant_name': 'Aaron Gordon'},
#      {'timestamp': '2024-01-27T02:40:23.489081',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 1.5,
#       'participant': 401,
#       'participant_name': 'Kentavious Caldwell-Pope'},
#      {'timestamp': '2024-01-27T01:35:21.782584',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 0.5,
#       'participant': 502,
#       'participant_name': 'Kevin Fiala'},
#      {'timestamp': '2024-01-27T02:05:24.991673',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 0.5,
#       'participant': 506,
#       'participant_name': 'Anze Kopitar'},
#      {'timestamp': '2024-01-26T21:25:22.732228',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 6.0,
#       'participant': 769,
#       'participant_name': 'Malcolm Brogdon'},
#      {'timestamp': '2024-01-27T02:40:23.490474',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 2.5,
#       'participant': 10856,
#       'participant_name': 'Alex Anzalone'},
#      {'timestamp': '2024-01-27T02:40:23.489489',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 2.0,
#       'participant': 11519,
#       'participant_name': 'Justin Reid'},
#      {'timestamp': '2024-01-27T02:40:23.489522',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 3.0,
#       'participant': 11521,
#       'participant_name': 'Nick Bolton'},
#      {'timestamp': '2024-01-27T02:40:23.489555',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 2.5,
#       'participant': 11692,
#       'participant_name': 'Roquan Smith'},
#      {'timestamp': '2024-01-27T01:50:28.032137',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 5.0,
#       'participant': 16160,
#       'participant_name': 'Scoot Henderson'},
#      {'timestamp': '2024-01-27T01:45:26.480873',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 6.5,
#       'participant': 16162,
#       'participant_name': 'Anfernee Simons'},
#      {'timestamp': '2024-01-27T01:15:21.400151',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 3.0,
#       'participant': 16257,
#       'participant_name': 'Victor Wembanyama'},
#      {'timestamp': '2024-01-27T01:15:21.400214',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 4.5,
#       'participant': 16258,
#       'participant_name': 'Devin Vassell'},
#      {'timestamp': '2024-01-27T00:40:25.968934',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 3.5,
#       'participant': 16259,
#       'participant_name': 'Jeremy Sochan'},
#      {'timestamp': '2024-01-26T09:15:21.735788',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 7.0,
#       'participant': 16260,
#       'participant_name': 'Tre Jones'},
#      {'timestamp': '2024-01-27T01:15:21.400294',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 2.0,
#       'participant': 16554,
#       'participant_name': 'Keldon Johnson'},
#      {'timestamp': '2024-01-27T01:15:21.400372',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 2.0,
#       'participant': 16733,
#       'participant_name': 'Zach Collins'},
#      {'timestamp': '2024-01-27T02:40:23.489287',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 1.5,
#       'participant': 16830,
#       'participant_name': 'Taurean Prince'},
#      {'timestamp': '2024-01-27T01:50:28.032748',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 1.5,
#       'participant': 16980,
#       'participant_name': 'Matisse Thybulle'},
#      {'timestamp': '2024-01-27T01:15:21.400636',
#       'game_id': '91b45a8b36a95c8e27ddb07042eba39d',
#       'line': 1.5,
#       'participant': 17203,
#       'participant_name': 'Cedi Osman'}]}}]}
