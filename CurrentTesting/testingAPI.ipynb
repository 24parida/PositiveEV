# %%
import requests
import urllib
from datetime import datetime

class myException(Exception):
    pass

class API:
    def __init__(self):
        self.BASE_URL = "https://api.prop-odds.com"
        self.API_KEY = "oQK8ATTYc0ug8atzBGvgLKPOKWCaVSMOpbnWPmnE8E"
    
    def setAPI(self, api):
        self.API_KEY = api

    #### first four methods are adapted from prop-odds @ https://github.com/M4THYOU/prop_odds_python_example/blob/main/main.py
    def get_request(self, url):
        response = requests.get(url)
        if response.status_code == 200:
            return response.json()
        
        if response.status_code == 401:
            raise myException("ERROR 401")
        raise myException(f"ERROR {response.status_code}")


    def get_nba_games(self):
        now = datetime.now()
        query_params = {
            'date': now.strftime('%Y-%m-%d'),
            'tz': 'America/New_York',
            'api_key': self.API_KEY,
        }
        params = urllib.parse.urlencode(query_params)
        url = self.BASE_URL + '/beta/games/nba?' + params
        print(url)
        return self.get_request(url)

    def get_most_recent_odds(self, game_id, market):
        query_params = {
            'api_key': self.API_KEY,
        }
        params = urllib.parse.urlencode(query_params)
        url = self.BASE_URL + '/beta/odds/' + game_id + '/' + market + '?' + params
        return self.get_request(url)

    def get_fantasy_lines(self, game_id, market):
        query_params = {
            'api_key': self.API_KEY,
        }

        params = urllib.parse.urlencode(query_params)
        url = self.BASE_URL + '/beta/fantasy_lines/' + game_id + '/' + market + '?' + params
        return self.get_request(url)
    
    def new_get_fantasy_lines(self, leauge):
        query_params = {
            'api_key': self.API_KEY,
        }

        params = urllib.parse.urlencode(query_params)
        url = self.BASE_URL + '/v1/fantasy_snapshot/' + leauge + '?' + params
        return self.get_request(url)

# %%
api = API()
data = api.new_get_fantasy_lines("NBA")["fantasy_books"]
for i in data:
    print(i)
# Out:
# {'bookie_key': 'draftkings', 'markets': [{'market_key': 'player_assists_over_under', 'lines': [{'timestamp': '2024-01-29T13:40:03.041307', 'game_id': '2930ea032308dc03ec37c0d232fd28d2', 'line': 5.5, 'participant': 364, 'participant_name': "D'Angelo Russell"}, {'timestamp': '2024-01-29T13:40:03.043380', 'game_id': '31860ff42dca7e5754919f25e96458e9', 'line': 3.5, 'participant': 366, 'participant_name': 'Jordan Poole'}, {'timestamp': '2024-01-29T13:40:03.041538', 'game_id': '2930ea032308dc03ec37c0d232fd28d2', 'line': 3.5, 'participant': 367, 'participant_name': 'Anthony Davis'}, {'timestamp': '2024-01-29T13:40:03.045071', 'game_id': '3165289a0aaf6f21905d51b0f41c589f', 'line': 2.5, 'participant': 368, 'participant_name': 'Donte Divincenzo'}, {'timestamp': '2024-01-29T13:40:03.042036', 'game_id': '2930ea032308dc03ec37c0d232fd28d2', 'line': 4.5, 'participant': 374, 'participant_name': 'Austin Reaves'}, {'timestamp': '2024-01-29T13:40:03.044983', 'game_id': '3165289a0aaf6f21905d51b0f41c589f', 'line': 7.5, 'participant': 376, 'participant_name': 'Jalen Brunson'}, {'timestamp': '2024-01-29T13:40:03.039205', 'game_id': 'b12e4acb4ce181bf6d8db1b6439babe2', 'line': 5.5, 'participant': 377, 'participant_name': 'Kevin Durant'}, {'timestamp': '2024-01-29T22:10:02.787056', 'game_id': '9af8c3e3063e642e44a81fae75596085', 'line': 1.5, 'participant': 379, 'participant_name': 'Deandre Ayton'}, {'timestamp': '2024-01-29T13:40:03.041446', 'game_id': '2930ea032308dc03ec37c0d232fd28d2', 'line':
1', 'line': 7.5, 'participant': 391, 'participant_name': 'Jamal Murray'}, {'timestamp': '2024-01-29T04:10:17.249185', 'game_id': 'b12e4acb4ce181bf6d8db1b6439babe2', 'line': 4.0, 'participant': 393, 'participant_name': 'Bam Adebayo'}, {'timestamp': '2024-01-17T16:20:06.664789', 'game_id': '6a84df3782bc046cf5bda47fc177862d', 'line': 6.0, 'participant': 394, 'participant_name': 'Stephen Curry'}, {'timestamp': '2024-01-29T05:55:22.533730', 'game_id': '9d2630cd07f94c63fe78f86f9cb7a3da', 'line': 5.0, 'participant': 395, 'participant_name': "De'Aaron Fox"}, {'timestamp': '2024-01-29T17:00:27.119891', 'game_id': '9d2630cd07f94c63fe78f86f9cb7a3da', 'line': 5.0, 'participant': 396, 'participant_name': 'Malik Monk'}, {'timestamp': '2024-01-29T22:40:27.715085', 'game_id': 'b12e4acb4ce181bf6d8db1b6439babe2', 'line': 4.5, 'participant': 398, 'participant_name': 'Jimmy Butler'}, {'timestamp': '2024-01-29T04:40:27.177609', 'game_id': '9d2630cd07f94c63fe78f86f9cb7a3da', 'line': 8.5, 'participant': 400, 'participant_name': 'Domantas Sabonis'}, {'timestamp': '2024-01-29T02:00:13.770154', 'game_id': '31860ff42dca7e5754919f25e96458e9', 'line': 8.0, 'participant': 413, 'participant_name': 'Tyus Jones'}, {'timestamp': '2024-01-28T23:10:21.168192', 'game_id': '708a5e76ac8200cde7aa41d4dc220f87', 'line': 3.5, 'participant': 462, 'participant_name': 'Max Strus'}, {'timestamp': '2024-01-29T23:30:23.483508', 'game_id': '3165289a0aaf6f21905d51b0f41c589f', 'line': 2.5, 'participant': 760, 'participant_name': 'Isaiah Hartenstein'}, {'timestamp': '2024-01-29T23:30:23.483195', 'game_id': '3165289a0aaf6f21905d51b0f41c589f', 'line': 4.0, 'participant': 764, 'participant_name': 'Josh Hart'}, {'timestamp': '2024-01-29T22:45:23.702036', 'game_id': '9b5e24c7c1d43157bb7492e844cec929', 'line': 4.0, 'participant': 766, 'participant_name': 'Derrick White'}, {'timestamp': '2024-01-29T22:50:28.040723', 'game_id': '9b5e24c7c1d43157bb7492e844cec929', 'line': 3.0, 'participant': 768, 'participant_name': 'Al Horford'}, {'timestamp': '2024-01-29T16:25:29.042070', 'game_id': '9af8c3e3063e642e44a81fae75596085', 'line': 6.0, 'participant': 769, 'participant_name': 'Malcolm Brogdon'}, {'timestamp': '2024-01-29T20:50:28.940679', 'game_id': '9af8c3e3063e642e44a81fae75596085', 'line': 4.5, 'participant': 835, 'participant_name': 'Tobias Harris'}, {'timestamp': '2024-01-29T17:45:23.528522', 'game_id': '708a5e76ac8200cde7aa41d4dc220f87', 'line': 8.5, 'participant': 836, 'participant_name': 'James Harden'}, {'timestamp': '2024-01-29T15:45: ...

# %%
## test Santi Aldama
